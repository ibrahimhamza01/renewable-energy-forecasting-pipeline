# %%
# !pwd
# Out:
# /home/syed/GWU/Spring 2026/Big Data Analytics/renewable-energy-forecasting-pipeline/notebooks

# %%
import pandas as pd

df = pd.read_csv("../data/raw/isd_sample/2025/99999963894.csv")
df.head()
# Out:
# /tmp/ipykernel_19768/3529323841.py:3: DtypeWarning: Columns (0: AB1, 1: AE1, 2: KB1, 3: KB2, 4: KB3, 5: KC1, 6: KC2, 7: KD1, 8: KD2, 9: KE1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/raw/isd_sample/2025/99999963894.csv")
#        STATION                 DATE SOURCE  LATITUDE  LONGITUDE  ELEVATION  \
# 0  99999963894  2025-01-01T00:00:00      I   34.7728   -87.6399      161.5
# 1  99999963894  2025-01-01T00:05:00      I   34.7728   -87.6399      161.5
# 2  99999963894  2025-01-01T00:10:00      I   34.7728   -87.6399      161.5
# 3  99999963894  2025-01-01T00:15:00      I   34.7728   -87.6399      161.5
# 4  99999963894  2025-01-01T00:20:00      I   34.7728   -87.6399      161.5
#
#                        NAME REPORT_TYPE  CALL_SIGN QUALITY_CONTROL  ...  KB1  \
# 0  MUSCLE SHOALS 2 N, AL US       CRN05      99999            V020  ...  NaN
# 1  MUSCLE SHOALS 2 N, AL US       CRN05      99999            V020  ...  NaN
# ...

# %%
df.iloc[0]
# Out:
# STATION                                         99999963894
# DATE                                    2025-01-01T00:00:00
# SOURCE                                                    I
# LATITUDE                                            34.7728
# LONGITUDE                                          -87.6399
# ELEVATION                                             161.5
# NAME                               MUSCLE SHOALS 2 N, AL US
# REPORT_TYPE                                           CRN05
# CALL_SIGN                                             99999
# QUALITY_CONTROL                                        V020
# WND                                          324,1,H,0051,1
# CIG                                             99999,9,9,N
# VIS                                            999999,9,9,9
# TMP                                                 +0093,1
# DEW                                                 +9999,9
# SLP                                                 99999,9
# ...
